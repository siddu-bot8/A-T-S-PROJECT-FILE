# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df =pd.read_csv('movie_ratings.csv')

# %%
df.sample(5)
# Out:
#     UserID     Movie   Genre  Rating  WatchHours SubscriptionType  Device
# 40    3041  Movie_41  Sci-Fi     4.9           4            Basic      TV
# 56    3057  Movie_57  Comedy     4.7          18            Basic  Laptop
# 70    3071  Movie_71  Sci-Fi     4.6           7          Premium  Mobile
# 11    3012  Movie_12  Sci-Fi     3.4          12          Premium      TV
# 66    3067  Movie_67  Sci-Fi     1.1           2            Basic  Mobile

# %%
df.shape
# Out:
# (100, 7)

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   UserID            100 non-null    int64
#  1   Movie             100 non-null    str
#  2   Genre             100 non-null    str
#  3   Rating            100 non-null    float64
#  4   WatchHours        100 non-null    int64
#  5   SubscriptionType  100 non-null    str
#  6   Device            100 non-null    str
# dtypes: float64(1), int64(2), str(4)
# memory usage: 5.6 KB

# %% [markdown]
# # NUMPY

# %%
df.head()
# Out:
#    UserID    Movie   Genre  Rating  WatchHours SubscriptionType  Device
# 0    3001  Movie_1  Horror     1.6          15          Premium  Laptop
# 1    3002  Movie_2   Drama     3.6          11            Basic  Laptop
# 2    3003  Movie_3  Horror     2.6           4            Basic      TV
# 3    3004  Movie_4  Comedy     2.5          15          Premium  Laptop
# 4    3005  Movie_5  Comedy     3.0           4          Premium  Laptop

# %%
np.average(df['Rating'])
# Out:
# np.float64(2.9909999999999997)

# %%
np.max(df['WatchHours'])
# Out:
# np.int64(19)

# %%
np.min(df['Rating'])
# Out:
# np.float64(1.0)

# %% [markdown]
# # PANDAS

# %%
df.sample(3)
# Out:
#     UserID     Movie   Genre  Rating  WatchHours SubscriptionType  Device
# 86    3087  Movie_87  Comedy     3.6           4            Basic  Laptop
# 30    3031  Movie_31  Sci-Fi     4.6           7            Basic  Mobile
# 74    3075  Movie_75  Sci-Fi     1.2           2            Basic      TV

# %%
df.groupby('Genre')['Rating'].mean()
# Out:
# Genre
# Action    2.868750
# Comedy    2.932000
# Drama     2.669565
# Horror    3.026667
# Sci-Fi    3.480952
# Name: Rating, dtype: float64

# %%
# df[df['SubscriptionType']== 'Premium'].count()

# %%
df['SubscriptionType'].value_counts()['Premium']
# Out:
# np.int64(41)

# %%
df.loc[df['Rating'] > 4, ['Movie', 'Genre','Rating']].head()
# Out:
#        Movie   Genre  Rating
# 5    Movie_6  Sci-Fi     4.6
# 13  Movie_14  Sci-Fi     4.4
# 14  Movie_15  Sci-Fi     4.9
# 25  Movie_26  Sci-Fi     4.2
# 26  Movie_27  Action     4.8

# %%
df.groupby('Device')['UserID'].count()
# Out:
# Device
# Laptop    27
# Mobile    34
# TV        39
# Name: UserID, dtype: int64

# %%
df.sort_values(by='WatchHours',ascending=False).head(10)
# Out:
#     UserID     Movie   Genre  Rating  WatchHours SubscriptionType  Device
# 27    3028  Movie_28  Horror     3.5          19            Basic  Mobile
# 25    3026  Movie_26  Sci-Fi     4.2          19          Premium      TV
# 19    3020  Movie_20   Drama     2.2          19            Basic  Mobile
# 17    3018  Movie_18   Drama     1.8          19          Premium      TV
# 83    3084  Movie_84  Sci-Fi     2.9          19          Premium  Laptop
# 59    3060  Movie_60  Comedy     4.9          19            Basic  Laptop
# 56    3057  Movie_57  Comedy     4.7          18            Basic  Laptop
# 10    3011  Movie_11  Action     2.3          17            Basic  Laptop
# 44    3045  Movie_45   Drama     2.5          17            Basic      TV
# 26    3027  Movie_27  Action     4.8          17          Premium      TV

# %%
df.nlargest(10, 'WatchHours')
# Out:
#     UserID     Movie   Genre  Rating  WatchHours SubscriptionType  Device
# 17    3018  Movie_18   Drama     1.8          19          Premium      TV
# 19    3020  Movie_20   Drama     2.2          19            Basic  Mobile
# 25    3026  Movie_26  Sci-Fi     4.2          19          Premium      TV
# 27    3028  Movie_28  Horror     3.5          19            Basic  Mobile
# 59    3060  Movie_60  Comedy     4.9          19            Basic  Laptop
# 83    3084  Movie_84  Sci-Fi     2.9          19          Premium  Laptop
# 56    3057  Movie_57  Comedy     4.7          18            Basic  Laptop
# 10    3011  Movie_11  Action     2.3          17            Basic  Laptop
# 26    3027  Movie_27  Action     4.8          17          Premium      TV
# 44    3045  Movie_45   Drama     2.5          17            Basic      TV

# %% [markdown]
# # MATPLOTLIB

# %%
df.sample(3)
# Out:
#     UserID     Movie   Genre  Rating  WatchHours SubscriptionType  Device
# 83    3084  Movie_84  Sci-Fi     2.9          19          Premium  Laptop
# 8     3009   Movie_9  Sci-Fi     2.2           9            Basic  Laptop
# 26    3027  Movie_27  Action     4.8          17          Premium      TV

# %%
genre_counts = df['Genre'].value_counts()

# Plot bar chart
plt.figure(figsize=(7,5))
genre_counts.plot(kind='bar', color='skyblue', edgecolor='black')
plt.title("Genre Distribution")
plt.xlabel("Genre")
plt.ylabel("Number of Movies")
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.hist(df['Rating'], bins=5, color='orange', edgecolor='black')
plt.title("Ratings Distribution")
plt.xlabel("Rating")
plt.ylabel("Number of Movies")
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.show()

# %%
device_counts = df['Device'].value_counts()

# Plot pie chart
plt.figure(figsize=(6,6))
plt.pie(device_counts, labels=device_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Device Usage Distribution")
plt.show()
